# %%
#https://github.com/yousefkotp/Visual-Question-Answering

# %%
# !pip install Levenshtein -q
# !pip install git+https://github.com/openai/CLIP.git -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 11.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 40.7 MB/s eta 0:00:00
#   Building wheel for clip (setup.py) ... done

# %%
# Importing os, numpy and pandas for data manipulation
import os
import numpy as np
import pandas as pd

from tqdm import tqdm
tqdm.pandas()
import time

# For data visualization, we will use matplotlib, wordcloud
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# For data preprocessing, we will use Counter, train_test_split, Levenshtein distance, Python Image Library and OneHotEncoder
from collections import Counter
import Levenshtein as lev
from PIL import Image
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# For saving and loading the preprocessed data, we will use pickle
import pickle

# For Building the model, we will use PyTorch and its functions
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import clip
from torch.utils.data import Dataset, DataLoader

# For taking the image from the URL, we will use requests
import requests

# For evaluation, we will need sklearn.metrics.average_precision_score
from sklearn.metrics import average_precision_score

# Importing json for results formatting which will be uploaded for evaluation
import json

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Check if the directory exists and copy if it does not exist
import os
import shutil

# List of files to copy
files = ["train.json", "train.zip", "valid.json", "valid.zip"]

# Source directory
src_dir = "drive/MyDrive/matsuo-ken-2024-DL/VQA/VQA"

# Destination directory
dest_dir = "./data"

# Ensure the destination directory exists
if not os.path.exists(dest_dir):
    os.makedirs(dest_dir)

# Copy files one by one
for file in files:
    src_file = os.path.join(src_dir, file)
    dest_file = os.path.join(dest_dir, file)

    if not os.path.exists(dest_file):
        shutil.copy(src_file, dest_file)
        print(f"{file} copied.")
    else:
        print(f"{file} already exists, not copying.")
# Out:
# train.json copied.
# train.zip copied.
# valid.json copied.
# valid.zip copied.

# %%
# Check if the train.zip file has been unzipped
# !if [[ -f "./data/train.zip" && ! -d "./data/train" ]]; then \
  unzip -q ./data/train.zip -d ./data; \
else \
  echo "train.zip already unzipped or not found."; \
fi

# Check if the valid.zip file has been unzipped
# !if [[ -f "./data/valid.zip" && ! -d "./data/valid" ]]; then \
  unzip -q ./data/valid.zip -d ./data; \
else \
  echo "valid.zip already unzipped or not found."; \
fi

# %%
# Configuring the paths for the dataset
INPUT_PATH = './data'
ANNOTATIONS = INPUT_PATH + ''
TRAIN_PATH = INPUT_PATH + '/train'
VALIDATION_PATH = INPUT_PATH + '/valid'
ANNOTATIONS_TRAIN_PATH = INPUT_PATH + '/train.json'
ANNOTATIONS_VAL_PATH = INPUT_PATH + '/valid.json'
OUTPUT_PATH = '/content/drive/MyDrive/matsuo-ken-2024-DL/VQA/OPENAI_CLIP/'
ANSWER_SPACE = 0 # Will be configured later when we build the vocab using the methodology described in the paper
MODEL_NAME = "ViT-L/14@336px" # This is the backbone of the CLIP model

# Using accelerated computing if available
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device: ", DEVICE)
# Out:
# Device:  cuda

# %% [markdown]
# #EDA

# %%
def read_dataframe(path):
    """
    Reads the JSON file and returns a dataframe with the required columns (image, question, answers)

    Parameters:
        path (str): Path to the JSON file

    Returns:
        df (pandas.DataFrame): Dataframe with the required columns
    """
    df = pd.read_json(path)
    df = df[['image', 'question', 'answers']]
    return df

def split_train_test(dataframe, test_size = 0.05):
    """
    Splits the dataframe into train and test sets

    Parameters:
        dataframe (pandas.DataFrame): Dataframe to be split

    Returns:
        train (pandas.DataFrame): Train set
        test (pandas.DataFrame): Test set
    """
    train, test = train_test_split(dataframe, test_size=test_size, random_state=42)
    return train, test

def plot_histogram(dataframe, column):
    """
    Plots the histogram of the given column

    Parameters:
        dataframe (pandas.DataFrame): Dataframe to be plotted
        column (str): Column to be plotted

    Returns:
        None
    """
    plt.hist(dataframe[column])
    plt.title(column)
    plt.show()

def plot_pie(dataframe, column):
    """
    Plots the pie chart of the given column

    Parameters:
        dataframe (pandas.DataFrame): Dataframe to be plotted
        column (str): Column to be plotted

    Returns:
        None
    """
    value_counts = dataframe[column].value_counts()
    plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%')
    plt.title(column)
    plt.show()

def plot_wordcloud(dataframe, column):
    """
    Plots the wordcloud of the given column

    Parameters:
        dataframe (pandas.DataFrame): Dataframe to be plotted
        column (str): Column to be plotted

    Returns:
        None
    """
    text = " ".join([word for word in dataframe[column]])

    wordcloud = WordCloud(width = 800, height = 800,
                    background_color ='white',
                    min_font_size = 10).generate(text)

    plt.figure(figsize = (8, 8), facecolor = None)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad = 0)
    plt.show()

def explore_dataframe(dataframe):
    """
    Explores the dataframe (EDA) by plotting the pie charts, histograms and wordclouds of the columns

    Parameters:
        dataframe (pandas.DataFrame): Dataframe to be explored

    Returns:
        None
    """
    # plot_pie(dataframe, 'answer_type')
    # plot_pie(dataframe, 'answerable')
    # plot_histogram(dataframe, 'answerable')
    plot_wordcloud(dataframe, 'question')

def get_number_of_distinct_answers(dataframe):
    """
    Returns the number of distinct answers in the dataframe

    Parameters:
        dataframe (pandas.DataFrame): Dataframe to be explored

    Returns:
        len(unique_answers_set) (int): Number of distinct answers in the dataframe
    """
    unique_answers_set = set()
    for row in dataframe['answers']:
        for answer_map in row:
            unique_answers_set.add(answer_map['answer'])
    return len(unique_answers_set)

def process_images(dataframe, image_path, clip_model, preprocessor, device):
    """
    Processes the images in the dataframe and returns the image features

    Parameters:
        dataframe (pandas.DataFrame): Dataframe containing the images
        image_path (str): Path to the input images
        clip_model (clip.model.CLIP): CLIP model
        preprocessor (clip.model.Preprocess): Preprocessor for the CLIP model
        device (torch.device): Device to be used for processing

    Returns:
        images (list): List of image features
    """
    images = []
    for _, row in tqdm(dataframe.iterrows(), total=len(dataframe)):
        full_path = image_path + "/" + row['image']
        image = Image.open(full_path)
        image = preprocessor(image).unsqueeze(0).to(device)
        image_features = clip_model.encode_image(image)
        image_features = torch.flatten(image_features, start_dim=1)
        images.append(image_features)
    return images

def process_questions(dataframe, clip_model,device):
    """
    Processes the questions in the dataframe and returns the question features

    Parameters:
        dataframe (pandas.DataFrame): Dataframe containing the questions
        clip_model (clip.model.CLIP): CLIP model
        device (torch.device): Device to be used for processing

    Returns:
        questions (list): List of question features
    """
    questions = []
    for _, row in tqdm(dataframe.iterrows(), total=len(dataframe)):
        question = row['question']
        question =  clip.tokenize(question).to(device)
        text_features = clip_model.encode_text(question).float()
        text_features = torch.flatten(text_features, start_dim=1)
        questions.append(text_features)
    return questions

# %%
train_df = read_dataframe(ANNOTATIONS_TRAIN_PATH)
# train_df, test_df = split_train_test(train_df, test_size=0.04)
test_df = train_df[:1000]
validation_df = test_df[:int(len(test_df)*0.5)]
ANSWER_SPACE = get_number_of_distinct_answers(train_df) # The answer space will be decreased later when we process the answers
print("Number of distinct answers: ", ANSWER_SPACE)
# Out:
# Number of distinct answers:  40359

# %%
train_df.head()
# Out:
#              image                                           question  \
# 0  train_00000.jpg                                      What is this?
# 1  train_00001.jpg  maybe it's because you're pushing it down instead
# 2  train_00002.jpg                           What color is this item?
# 3  train_00003.jpg  Can you tell me if this is like body wash or l...
# 4  train_00004.jpg                                     Is it a paper?
#
#                                              answers
# 0  [{'answer_confidence': 'yes', 'answer': 'beef ...
# 1  [{'answer_confidence': 'yes', 'answer': 'unans...
# 2  [{'answer_confidence': 'yes', 'answer': 'grey'...
# 3  [{'answer_confidence': 'maybe', 'answer': 'lot...
# 4  [{'answer_confidence': 'yes', 'answer': 'no'},...

# %%
explore_dataframe(train_df)
print("Number of distinct answers: ", get_number_of_distinct_answers(train_df))
print("Number of samples in train: ", len(train_df))

# %% [markdown]
# # DATASET AND MODEL

# %%
class VizWizDataset(Dataset):
    def __init__(self, dataframe, answer_onehotencoder = None, model_name = "ViT-L/14@336px", image_path = None, transform = None):
        super(VizWizDataset, self).__init__()

        self.dataframe = dataframe
        self.transform = transform
        self.image_path = image_path

        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model, self.preprocessor = clip.load(model_name, device = self.device)

        self.image_list, self.question_list = self.preprocess()

        # Total counter for all answers before filtering, used in Tie Breaking when building the answer vocabulary
        self.answer_counter = Counter()


        # List for answers for each question (each question has 10 answers)
        self.answer_counter_per_question = []

        # Populating the counter for words in answers which will be used when building answer vocabulary
        self.build_answer_counter()

        # Building the answer vocabulary according to the methodology explained in the paper
        self.build_answer_vocab()

        # The number of vocabulary words after filtering
        print("Number of distinct answers: ", len(self.get_answer_vocab()))

        # One hot encoding the answer
        if answer_onehotencoder is None:
            answer_onehotencoder = OneHotEncoder(handle_unknown='ignore')
            answer_onehotencoder.fit(self.copied_dataframe[['answer']])

        # Saving the one hot encoders
        self.answer_onehotencoder = answer_onehotencoder

        # Transforming the answers and answer types to one hot encoded vectors
        self.answer_onehotencoded = answer_onehotencoder.transform(self.copied_dataframe[['answer']]).toarray()

        # Saving the answer categories (vocabulary) which will be used when getting index of the predicted answer
        self.answers_categories = self.answer_onehotencoder.categories_[0].tolist()

        # Saving answers for each question (each question has 10 answers)
        self.build_answer_counter_per_question()

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, index):
        image = self.image_list[index]
        question = self.question_list[index]
        answer = torch.tensor(self.answer_onehotencoded[index], dtype=torch.float32)
        answer_counter = torch.tensor(self.answer_counter_per_question[index], dtype=torch.long)
        return image, question, answer, answer_counter

    def preprocess(self):
        image_list = []
        question_list = clip.tokenize(self.dataframe['question'].tolist())
        for index, row in tqdm(self.dataframe.iterrows(), total=len(self.dataframe)):
            image = self.preproc_image(row['image'])
            image_list.append(image)

            torch.cuda.empty_cache()

        return image_list, question_list

    def preproc_image(self, image_path):
        image = Image.open(self.image_path + "/" + image_path)
        if self.transform:
            image = self.transform(image)
        image = self.preprocessor(image).unsqueeze(0)
        torch.cuda.empty_cache()
        return image

    def build_answer_counter_per_question(self):
        for index, row in self.dataframe.iterrows():
            temp_list = []
            for answer_map in row['answers']:
                answer = answer_map['answer']
                # check if answer in self.answers_categories
                if answer in self.answers_categories:
                    answer_index = self.answers_categories.index(answer)
                    temp_list.append(answer_index)
            # Torch.tensor requires the all the lists to have constant length, so we pad the list with -1 if needed
            while len(temp_list) < 10:
                temp_list.append(-1)
            self.answer_counter_per_question.append(temp_list)

    def build_answer_vocab(self):
        # Building answer vocab follow this policy:
        # for each question we have 10 answers, we choose the most frequent answer as the answer for this question
        # if there is a tie, we choose the most common one in the whole dataset
        # if there is a tie, we choose the pairwise Levenshtein distance is used to find the answer that is most representative to all others.

        # Copying the original dataframe which will be manipulated
        self.copied_dataframe = self.dataframe.copy()
        self.copied_dataframe.drop(columns=['answers'], inplace=True)

        # Adding extra column named 'answer'
        self.copied_dataframe['answer'] = None

        for index, row in self.dataframe.iterrows():
            intermediate_counter = Counter()
            for answer_map in row['answers']:
                answer = answer_map['answer']
                intermediate_counter.update([answer])

            # let's see the top elements in the answers_counter to check if there is a tie
            top_elements = intermediate_counter.most_common(1)
            if len(top_elements) == 1:
                self.copied_dataframe.at[index, 'answer'] = top_elements[0][0]
            else:
                # let's see who is the most common answer in the whole dataset
                top_elements = self.answer_counter.most_common(1)
                if len(top_elements) == 1:
                    self.copied_dataframe.at[index, 'answer'] = top_elements[0][0]
                else:
                    # let's get the minimum levenshtein distance between the answers in top_elements
                    current_min = np.inf
                    current_answer = None
                    for answer in top_elements:
                        total_distance = 0
                        for answer2 in top_elements:
                            if answer != answer2:
                                lev_distance = lev.distance(answer[0], answer2[0])
                                total_distance += lev_distance
                        if total_distance < current_min:
                            current_min = total_distance
                            current_answer = answer[0]
                    self.copied_dataframe.at[index, 'answer'] = current_answer
        return

    def build_answer_counter(self):
        for row in self.dataframe['answers']:
            for answer_map in row:
                self.answer_counter.update([answer_map['answer']])

    def get_answer_vocab(self):
        return self.copied_dataframe['answer'].unique()

# %%
class VQAModel(nn.Module):

    def __init__(self, num_classes, hidden_size, model_name = "ViT-L/14@336px", device = torch.device("cpu")):
        super().__init__()

        self.training_losses = []
        self.validation_losses = []

        self.training_accuracies = []
        self.validation_accuracies = []

        self.vizwiz_training_accuracies = []
        self.vizwiz_validation_accuracies = []

        self.device = device
        self.model_name = model_name

        # Loading the CLIP model
        self.clip_model, self.preprocess = clip.load(model_name, device = device)

        # Freezing the CLIP model
        # for param in self.clip_model.parameters():
        #     param.requires_grad = False
        # Define the layers to keep trainable
        trainable_layers = ["ln_final"]
        # trainable_layers = ["ln_final"]

        # Freeze all layers except the specified ones
        for name, param in self.clip_model.named_parameters():
            if not any(layer in name for layer in trainable_layers) or "visual" in name:
                param.requires_grad = False

        # Check which layers are trainable
        for name, param in self.clip_model.named_parameters():
            if param.requires_grad:
                print(f"Trainable layer: {name}")

        # First linear layer
        self.linear_layer1 = nn.Sequential(
            nn.LayerNorm(self.clip_model.visual.output_dim + self.clip_model.text_projection.shape[1]),
            nn.Dropout(p=0.5),
            nn.Linear(self.clip_model.visual.output_dim + self.clip_model.text_projection.shape[1], hidden_size)
        )

        # Second linear layer
        self.linear_layer2 = nn.Sequential(
            nn.LayerNorm(hidden_size),
            nn.Dropout(p=0.5),
            nn.Linear(hidden_size, num_classes)
        )

        self.sigmoid = nn.Sigmoid()

    def forward(self, image, question):
        if image.dim() == 5:
            image = image.squeeze(1)  # Remove the unnecessary dimension

        # Encoding the image and question using the CLIP model
        image_features = self.clip_model.encode_image(image)
        image_features = torch.flatten(image_features, start_dim=1)

        if question.dim() == 3:
            question = question.squeeze(1)  # Ensure correct shape for the question tensor
        question_features = self.clip_model.encode_text(question).float()
        question_features = torch.flatten(question_features, start_dim=1)

        features = torch.cat((image_features, question_features), dim=1)

        # Passing the features through the first linear layer
        features = self.linear_layer1(features)

        # Passing the features through the second linear layer
        output = self.linear_layer2(features)

        return output

    def train_model(self, training_dataloader, validation_dataloader, test_dataloader, criterion, optimizer, scheduler, epochs = 10, save_path = None, save_every = 1):
        for epoch in range(1,epochs+1):
            start = time.time()
            training_loss, training_accuracy, training_vizwiz_accuracy = self.training_step(training_dataloader, criterion, optimizer, scheduler, self.device)
            validation_loss, validation_accuracy, validation_vizwiz_accuracy = self.validation_step(validation_dataloader, criterion, self.device)
            test_accuracy, test_vizwiz_accuracy = self.test_step(test_dataloader)

            self.training_losses.append(training_loss)
            self.validation_losses.append(validation_loss)

            self.training_accuracies.append(training_accuracy)
            self.validation_accuracies.append(validation_accuracy)

            self.vizwiz_training_accuracies.append(training_vizwiz_accuracy)
            self.vizwiz_validation_accuracies.append(validation_vizwiz_accuracy)

            end = time.time()
            print("Epoch: {} | Training Loss: {:.3f} | Validation Loss: {:.3f} | Time {:.3f}".format(epoch, training_loss, validation_loss, end-start))
            print("Epoch: {} | Training Accuracy: {:.3f} | Validation Accuracy: {:.3f} | Test Accuracy: {:.3f}".format(epoch, training_accuracy, validation_accuracy, test_accuracy))
            print("Epoch: {} | Training VizWiz Accuracy: {:.3f} | Validation VizWiz Accuracy: {:.3f} | Test VizWiz Accuracy: {:.3f}".format(epoch, training_vizwiz_accuracy, validation_vizwiz_accuracy, test_vizwiz_accuracy))

            if save_path != None and epoch % save_every == 0:
                self.save_model(save_path + "epoch_{}.pth".format(epoch))
        return

    def training_step(self, dataloader, criterion, optimizer, scheduler, device):
        training_loss, training_accuracy, vizwiz_accuracy, total_sum = 0.0, 0.0, 0.0, 0
        self.train()
        step_count = 0
        for _, batch in enumerate(dataloader):
            step_count += 1
            image, question, answer, answers_for_questions = batch
            image, question, answer, answers_for_questions = image.to(device), question.to(device), answer.to(device), answers_for_questions.to(device)
            output = self.forward(image, question)
            loss = criterion(output, answer)
            loss.backward()
            if step_count % 4 == 0:
                optimizer.step()
                optimizer.zero_grad()
            training_loss += loss.item()
            predicted_answer = torch.argmax(output, dim = 1)
            actual_answer = torch.argmax(answer, dim = 1)
            for i in range(len(answer)):
                if actual_answer[i] == predicted_answer[i]:
                    training_accuracy +=1
                total_sum +=1
                vizwiz_accuracy += min(1, torch.sum(torch.eq(predicted_answer[i], answers_for_questions[i])).item()/3)

        scheduler.step()
        print(f"LR: {scheduler.get_last_lr()}\n")
        training_loss /= len(dataloader)
        training_accuracy /= total_sum
        vizwiz_accuracy /= total_sum

        return training_loss, training_accuracy, vizwiz_accuracy


    def validation_step(self, dataloader, criterion, device):
        validation_loss, validation_accuracy, vizwiz_accuracy, total_sum = 0.0, 0.0, 0.0, 0
        self.eval()
        with torch.no_grad():
            for _, batch in enumerate(dataloader):
                image, question, answer, answers_for_questions = batch
                image, question, answer, answers_for_questions = image.to(device), question.to(device), answer.to(device), answers_for_questions.to(device)
                output = self.forward(image, question)

                loss = criterion(output, answer)
                validation_loss += loss.item()
                predicted_answer = torch.argmax(output, dim = 1)
                actual_answer = torch.argmax(answer, dim = 1)
                for i in range(len(answer)):
                    if torch.sum(answer[i]) == 0:
                        continue
                    if actual_answer[i] == predicted_answer[i]:
                        validation_accuracy += 1
                    total_sum +=1
                    vizwiz_accuracy += min(1, torch.sum(torch.eq(predicted_answer[i], answers_for_questions[i])).item()/3)

        validation_loss /= len(dataloader)
        validation_accuracy /= total_sum
        vizwiz_accuracy /= total_sum

        return validation_loss, validation_accuracy, vizwiz_accuracy

    def test_step(self, dataloader):
        self.eval()
        accuracy, total_sum, vizwiz_accuracy = 0.0, 0, 0.0

        with torch.no_grad():
            for _, batch in enumerate(dataloader):
                image, question, answer, answers_for_questions = batch
                image, question, answer, answers_for_questions = image.to(self.device), question.to(self.device), answer.to(self.device), answers_for_questions.to(self.device)
                output = self.forward(image, question)

                predicted_answer = torch.argmax(output, dim = 1)
                actual_answer = torch.argmax(answer, dim = 1)
                for i in range(len(answer)):
                    if torch.sum(answer[i]) == 0:
                        continue
                    if predicted_answer[i] == actual_answer[i]:
                        accuracy += 1
                    vizwiz_accuracy += min(1, torch.sum(torch.eq(predicted_answer[i], answers_for_questions[i])).item()/3)
                    total_sum +=1


        accuracy /= total_sum
        vizwiz_accuracy /= total_sum
        return accuracy, vizwiz_accuracy

    def save_model(self, path):
        """
        Saves the model state dictionary to the given path.

        Args:
        - self: the model object
        - path (str): the path to save the model state dictionary

        Returns:
        - None
        """
        torch.save(self.state_dict(), path)

    def load_model(self, path):
        """
        Loads the model state dictionary from the given path.

        Args:
        - self: the model object
        - path (str): the path to load the model state dictionary

        Returns:
        - self: the loaded model object
        """
        self.load_state_dict(torch.load(path))
        self.eval()
        return self

    def predict(self, image, question):
        """
        Predicts the output and answer type for the given image and question.

        Args:
        - self: the model object
        - image (tensor): the image tensor
        - question (tensor): the question tensor

        Returns:
        - output (tensor): the predicted output tensor
        """
        output = self.forward(image, question)
        return output

    def plot_loss(self):
        """
        Plots the training and validation losses.

        Args:
        - self: the model object

        Returns:
        - None
        """
        plt.plot(self.training_losses, label = "Training Loss")
        plt.plot(self.validation_losses, label = "Validation Loss")
        plt.legend()
        plt.show()

    def plot_accuracy(self):
        """
        Plots the training and validation accuracies.

        Args:
        - self: the model object

        Returns:
        - None
        """
        plt.plot(self.training_accuracies, label = "Training Accuracy")
        plt.plot(self.validation_accuracies, label = "Validation Accuracy")
        plt.legend()
        plt.show()

    def plot_vizwiz_accuracy(self):
        """
        Plots the VizWiz training and validation accuracies.

        Args:
        - self: the model object

        Returns:
        - None
        """
        plt.plot(self.vizwiz_training_accuracies, label = "VizWiz Training Accuracy")
        plt.plot(self.vizwiz_validation_accuracies, label = "VizWiz Validation Accuracy")
        plt.legend()
        plt.show()

    def test_model(self, image_path, question):
        """
        Tests the model by predicting the answer and answer type for the given image and question.

        Args:
        - self: the model object
        - image_path (str): the path to the image file or URL
        - question (str): the question to be asked

        Returns:
        - predicted_answer (tensor): the predicted answer tensor
        """
        self.eval()
        if image_path.startswith("http"):
            image = Image.open(requests.get(image_path, stream = True).raw)
        else:
            image = Image.open(image_path)

        image = self.preprocess(image).unsqueeze(0).to(self.device)
        # image_features = self.clip_model.encode_image(image)
        # image_features = torch.flatten(image_features, start_dim=1)

        question =  clip.tokenize(question).to(self.device)
        # text_features = self.clip_model.encode_text(question).float()
        # text_features = torch.flatten(text_features, start_dim=1)

        predicted_answer = self.predict(image, question)
        return predicted_answer

    def print_CLIP_model(self):
        """
        Prints the details of the selected CLIP model.

        Args:
        - self: the model object

        Returns:
        - None
        """
        input_resolution = self.clip_model.visual.input_resolution
        context_length = self.clip_model.context_length
        vocab_size = self.clip_model.vocab_size

        print("Selected model:", self.model_name)
        print("Model parameters:", f"{np.sum([int(np.prod(p.shape)) for p in self.clip_model.parameters()]):,}")
        print("Input resolution:", input_resolution)
        print("Context length:", context_length)
        print("Vocab size:", vocab_size)
        print("")

# %%
# Constructing the training dataset
from torchvision import transforms
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.RandomRotation(15),
    transforms.RandomAffine(degrees=20, translate=(0.1, 0.1), scale=(0.8, 1.2)),
    ])

training_dataset = VizWizDataset(train_df, None, MODEL_NAME, TRAIN_PATH, transform=None)
# Building the answer counter and answer vocab
ANSWER_ONEHOTENCODER = training_dataset.answer_onehotencoder

# Saving the fitted one hot encoders
with open(OUTPUT_PATH + 'answer_onehotencoder.pkl', 'wb') as f:
    pickle.dump(ANSWER_ONEHOTENCODER, f)

# Constructing the validation dataset
validation_dataset = VizWizDataset(validation_df, ANSWER_ONEHOTENCODER, MODEL_NAME, TRAIN_PATH, None)

# Constructing the test dataset
test_dataset = VizWizDataset(test_df, ANSWER_ONEHOTENCODER, MODEL_NAME, TRAIN_PATH, None)
# Out:
# 100%|███████████████████████████████████████| 891M/891M [00:10<00:00, 90.0MiB/s]
# 100%|██████████| 19873/19873 [10:47<00:00, 30.67it/s]
# Number of distinct answers:  5313
# 100%|██████████| 500/500 [00:16<00:00, 30.48it/s]
# Number of distinct answers:  254
# 100%|██████████| 1000/1000 [00:31<00:00, 31.26it/s]
# Number of distinct answers:  452

# %%
# Configuring the data loaders
BATCH_SIZE = 64 # 64 is good too but 32 is better (variance wise)

# Constructing the training, validation and test data loaders
training_dataloader = DataLoader(training_dataset, batch_size=BATCH_SIZE, shuffle=True)
validation_dataloader = DataLoader(validation_dataset, batch_size=BATCH_SIZE)
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE)

# %%
# Configuring training's hyperparameters
NUM_EPOCHS = 100
LR = 5e-3
WEIGHT_DECAY = 0
NUM_CLASSES = len(training_dataset.get_answer_vocab())
SAVE_PATH = OUTPUT_PATH
SAVE_EVERY = 100

# Initializing the model
model = VQAModel(num_classes=NUM_CLASSES, device= DEVICE, hidden_size=256, model_name=MODEL_NAME).to(DEVICE)
model.print_CLIP_model()

# Initializing the loss function and optimizer
loss_function = nn.CrossEntropyLoss().to(DEVICE)
optimizer = optim.Adam(model.parameters(), lr=LR, weight_decay = WEIGHT_DECAY)
scheduler = optim.lr_scheduler.OneCycleLR(optimizer, max_lr=LR, epochs=NUM_EPOCHS, steps_per_epoch=len(training_dataloader), pct_start=0.3, anneal_strategy='cos')

# Training the model and plotting the loss and accuracy
model.train_model(training_dataloader, validation_dataloader, test_dataloader, loss_function, optimizer, scheduler, epochs=NUM_EPOCHS, save_path=SAVE_PATH, save_every=SAVE_EVERY)
model.plot_loss()
model.plot_accuracy()
model.plot_vizwiz_accuracy()
# Out:
# Trainable layer: ln_final.weight
# Trainable layer: ln_final.bias
# Selected model: ViT-L/14@336px
# Model parameters: 427,944,193
# Input resolution: 336
# Context length: 77
# Vocab size: 49408
#
# LR: [0.0002000001360851697]
#
# Epoch: 1 | Training Loss: 6.080 | Validation Loss: 5.362 | Time 664.302
# Epoch: 1 | Training Accuracy: 0.357 | Validation Accuracy: 0.372 | Test Accuracy: 0.397
# Epoch: 1 | Training VizWiz Accuracy: 0.455 | Validation VizWiz Accuracy: 0.470 | Test VizWiz Accuracy: 0.498
# LR: [0.00020000054434066595]
#
# Epoch: 2 | Training Loss: 5.225 | Validation Loss: 5.130 | Time 662.045
# Epoch: 2 | Training Accuracy: 0.385 | Validation Accuracy: 0.376 | Test Accuracy: 0.401
# Epoch: 2 | Training VizWiz Accuracy: 0.491 | Validation VizWiz Accuracy: 0.475 | Test VizWiz Accuracy: 0.503
# LR: [0.00020000122476643983]
#
# Epoch: 3 | Training Loss: 5.011 | Validation Loss: 4.921 | Time 661.731
# Epoch: 3 | Training Accuracy: 0.388 | Validation Accuracy: 0.384 | Test Accuracy: 0.413
# Epoch: 3 | Training VizWiz Accuracy: 0.492 | Validation VizWiz Accuracy: 0.477 | Test VizWiz Accuracy: 0.510
# LR: [0.0002000021773624159]
#
# Epoch: 4 | Training Loss: 4.819 | Validation Loss: 4.711 | Time 662.292
# Epoch: 4 | Training Accuracy: 0.393 | Validation Accuracy: 0.396 | Test Accuracy: 0.424
# Epoch: 4 | Training VizWiz Accuracy: 0.495 | Validation VizWiz Accuracy: 0.489 | Test VizWiz Accuracy: 0.519
# LR: [0.0002000034021284857]
#
# Epoch: 5 | Training Loss: 4.651 | Validation Loss: 4.482 | Time 661.546
# Epoch: 5 | Training Accuracy: 0.401 | Validation Accuracy: 0.400 | Test Accuracy: 0.432
# Epoch: 5 | Training VizWiz Accuracy: 0.502 | Validation VizWiz Accuracy: 0.492 | Test VizWiz Accuracy: 0.527
# LR: [0.0002000048990645105]
#
# Epoch: 6 | Training Loss: 4.463 | Validation Loss: 4.268 | Time 660.398
# Epoch: 6 | Training Accuracy: 0.410 | Validation Accuracy: 0.410 | Test Accuracy: 0.439
# Epoch: 6 | Training VizWiz Accuracy: 0.510 | Validation VizWiz Accuracy: 0.503 | Test VizWiz Accuracy: 0.536
# LR: [0.00020000666817032026]
#
# Epoch: 7 | Training Loss: 4.301 | Validation Loss: 4.060 | Time 660.916
# Epoch: 7 | Training Accuracy: 0.418 | Validation Accuracy: 0.416 | Test Accuracy: 0.447
# Epoch: 7 | Training VizWiz Accuracy: 0.519 | Validation VizWiz Accuracy: 0.508 | Test VizWiz Accuracy: 0.543
# LR: [0.00020000870944571463]
#
# Epoch: 8 | Training Loss: 4.163 | Validation Loss: 3.881 | Time 661.998
# Epoch: 8 | Training Accuracy: 0.422 | Validation Accuracy: 0.428 | Test Accuracy: 0.455
# Epoch: 8 | Training VizWiz Accuracy: 0.522 | Validation VizWiz Accuracy: 0.519 | Test VizWiz Accuracy: 0.552
# LR: [0.00020001102289046203]
#
# Epoch: 9 | Training Loss: 4.018 | Validation Loss: 3.697 | Time 661.743
# Epoch: 9 | Training Accuracy: 0.428 | Validation Accuracy: 0.436 | Test Accuracy: 0.461
# Epoch: 9 | Training VizWiz Accuracy: 0.527 | Validation VizWiz Accuracy: 0.523 | Test VizWiz Accuracy: 0.554
# LR: [0.00020001360850429965]
#
# Epoch: 10 | Training Loss: 3.896 | Validation Loss: 3.562 | Time 662.046
# Epoch: 10 | Training Accuracy: 0.435 | Validation Accuracy: 0.450 | Test Accuracy: 0.473
# Epoch: 10 | Training VizWiz Accuracy: 0.535 | Validation VizWiz Accuracy: 0.544 | Test VizWiz Accuracy: 0.570
# LR: [0.00020001646628693432]
#
# Epoch: 11 | Training Loss: 3.781 | Validation Loss: 3.416 | Time 660.454
# Epoch: 11 | Training Accuracy: 0.441 | Validation Accuracy: 0.462 | Test Accuracy: 0.481
# Epoch: 11 | Training VizWiz Accuracy: 0.540 | Validation VizWiz Accuracy: 0.552 | Test VizWiz Accuracy: 0.578
# LR: [0.00020001959623804338]
#
# Epoch: 12 | Training Loss: 3.668 | Validation Loss: 3.253 | Time 661.565
# Epoch: 12 | Training Accuracy: 0.447 | Validation Accuracy: 0.478 | Test Accuracy: 0.497
# Epoch: 12 | Training VizWiz Accuracy: 0.545 | Validation VizWiz Accuracy: 0.563 | Test VizWiz Accuracy: 0.591
# LR: [0.00020002299835727034]
#
# Epoch: 13 | Training Loss: 3.562 | Validation Loss: 3.136 | Time 660.878
# Epoch: 13 | Training Accuracy: 0.451 | Validation Accuracy: 0.482 | Test Accuracy: 0.499
# Epoch: 13 | Training VizWiz Accuracy: 0.548 | Validation VizWiz Accuracy: 0.565 | Test VizWiz Accuracy: 0.591
# LR: [0.00020002667264422923]
#
# Epoch: 14 | Training Loss: 3.464 | Validation Loss: 3.005 | Time 661.311
# Epoch: 14 | Training Accuracy: 0.457 | Validation Accuracy: 0.488 | Test Accuracy: 0.504
# Epoch: 14 | Training VizWiz Accuracy: 0.554 | Validation VizWiz Accuracy: 0.573 | Test VizWiz Accuracy: 0.598
# LR: [0.00020003061909850458]
#
# Epoch: 15 | Training Loss: 3.358 | Validation Loss: 2.883 | Time 661.336
# Epoch: 15 | Training Accuracy: 0.462 | Validation Accuracy: 0.498 | Test Accuracy: 0.513
# Epoch: 15 | Training VizWiz Accuracy: 0.559 | Validation VizWiz Accuracy: 0.581 | Test VizWiz Accuracy: 0.606
# LR: [0.0002000348377196471]
#
# Epoch: 16 | Training Loss: 3.268 | Validation Loss: 2.775 | Time 661.980
# Epoch: 16 | Training Accuracy: 0.472 | Validation Accuracy: 0.512 | Test Accuracy: 0.521
# Epoch: 16 | Training VizWiz Accuracy: 0.568 | Validation VizWiz Accuracy: 0.592 | Test VizWiz Accuracy: 0.613
# LR: [0.00020003932850718147]
#
# Epoch: 17 | Training Loss: 3.179 | Validation Loss: 2.639 | Time 661.992
# Epoch: 17 | Training Accuracy: 0.474 | Validation Accuracy: 0.516 | Test Accuracy: 0.525
# Epoch: 17 | Training VizWiz Accuracy: 0.570 | Validation VizWiz Accuracy: 0.599 | Test VizWiz Accuracy: 0.620
# LR: [0.0002000440914605951]
#
# Epoch: 18 | Training Loss: 3.079 | Validation Loss: 2.523 | Time 661.539
# Epoch: 18 | Training Accuracy: 0.482 | Validation Accuracy: 0.528 | Test Accuracy: 0.539
# Epoch: 18 | Training VizWiz Accuracy: 0.577 | Validation VizWiz Accuracy: 0.606 | Test VizWiz Accuracy: 0.630
# LR: [0.00020004912657934932]
#
# Epoch: 19 | Training Loss: 2.999 | Validation Loss: 2.410 | Time 662.134
# Epoch: 19 | Training Accuracy: 0.488 | Validation Accuracy: 0.536 | Test Accuracy: 0.549
# Epoch: 19 | Training VizWiz Accuracy: 0.582 | Validation VizWiz Accuracy: 0.614 | Test VizWiz Accuracy: 0.639
# LR: [0.00020005443386287344]
#
# Epoch: 20 | Training Loss: 2.936 | Validation Loss: 2.357 | Time 661.819
# Epoch: 20 | Training Accuracy: 0.488 | Validation Accuracy: 0.546 | Test Accuracy: 0.550
# Epoch: 20 | Training VizWiz Accuracy: 0.581 | Validation VizWiz Accuracy: 0.626 | Test VizWiz Accuracy: 0.642
# LR: [0.00020006001331056462]
#
# Epoch: 21 | Training Loss: 2.843 | Validation Loss: 2.189 | Time 661.698
# Epoch: 21 | Training Accuracy: 0.495 | Validation Accuracy: 0.576 | Test Accuracy: 0.574
# Epoch: 21 | Training VizWiz Accuracy: 0.589 | Validation VizWiz Accuracy: 0.653 | Test VizWiz Accuracy: 0.662
# LR: [0.00020006586492179144]
#
# Epoch: 22 | Training Loss: 2.760 | Validation Loss: 2.094 | Time 662.242
# Epoch: 22 | Training Accuracy: 0.502 | Validation Accuracy: 0.574 | Test Accuracy: 0.577
# Epoch: 22 | Training VizWiz Accuracy: 0.594 | Validation VizWiz Accuracy: 0.651 | Test VizWiz Accuracy: 0.666
# LR: [0.00020007198869588863]
#
# Epoch: 23 | Training Loss: 2.672 | Validation Loss: 2.021 | Time 662.361
# Epoch: 23 | Training Accuracy: 0.506 | Validation Accuracy: 0.574 | Test Accuracy: 0.582
# Epoch: 23 | Training VizWiz Accuracy: 0.598 | Validation VizWiz Accuracy: 0.657 | Test VizWiz Accuracy: 0.674
# LR: [0.00020007838463216316]
#
# Epoch: 24 | Training Loss: 2.593 | Validation Loss: 1.936 | Time 662.030
# Epoch: 24 | Training Accuracy: 0.513 | Validation Accuracy: 0.582 | Test Accuracy: 0.591
# Epoch: 24 | Training VizWiz Accuracy: 0.604 | Validation VizWiz Accuracy: 0.664 | Test VizWiz Accuracy: 0.681
# LR: [0.00020008505272988905]
#
# Epoch: 25 | Training Loss: 2.514 | Validation Loss: 1.809 | Time 661.679
# Epoch: 25 | Training Accuracy: 0.523 | Validation Accuracy: 0.616 | Test Accuracy: 0.615
# Epoch: 25 | Training VizWiz Accuracy: 0.611 | Validation VizWiz Accuracy: 0.691 | Test VizWiz Accuracy: 0.703
# LR: [0.00020009199298830996]
#
# Epoch: 26 | Training Loss: 2.446 | Validation Loss: 1.738 | Time 661.490
# Epoch: 26 | Training Accuracy: 0.528 | Validation Accuracy: 0.618 | Test Accuracy: 0.625
# Epoch: 26 | Training VizWiz Accuracy: 0.614 | Validation VizWiz Accuracy: 0.697 | Test VizWiz Accuracy: 0.712
# LR: [0.00020009920540664007]
#
# Epoch: 27 | Training Loss: 2.370 | Validation Loss: 1.620 | Time 661.204
# Epoch: 27 | Training Accuracy: 0.537 | Validation Accuracy: 0.634 | Test Accuracy: 0.641
# Epoch: 27 | Training VizWiz Accuracy: 0.623 | Validation VizWiz Accuracy: 0.707 | Test VizWiz Accuracy: 0.723
# LR: [0.0002001066899840597]
#
# Epoch: 28 | Training Loss: 2.320 | Validation Loss: 1.568 | Time 661.875
# Epoch: 28 | Training Accuracy: 0.540 | Validation Accuracy: 0.622 | Test Accuracy: 0.639
# Epoch: 28 | Training VizWiz Accuracy: 0.627 | Validation VizWiz Accuracy: 0.699 | Test VizWiz Accuracy: 0.718
# LR: [0.00020011444671972148]
#
# Epoch: 29 | Training Loss: 2.232 | Validation Loss: 1.425 | Time 662.205
# Epoch: 29 | Training Accuracy: 0.548 | Validation Accuracy: 0.666 | Test Accuracy: 0.671
# Epoch: 29 | Training VizWiz Accuracy: 0.633 | Validation VizWiz Accuracy: 0.733 | Test VizWiz Accuracy: 0.743
# LR: [0.00020012247561274413]
#
# Epoch: 30 | Training Loss: 2.173 | Validation Loss: 1.383 | Time 661.493
# Epoch: 30 | Training Accuracy: 0.556 | Validation Accuracy: 0.664 | Test Accuracy: 0.673
# Epoch: 30 | Training VizWiz Accuracy: 0.640 | Validation VizWiz Accuracy: 0.736 | Test VizWiz Accuracy: 0.749
# LR: [0.00020013077666221867]
#
# Epoch: 31 | Training Loss: 2.111 | Validation Loss: 1.322 | Time 662.065
# Epoch: 31 | Training Accuracy: 0.563 | Validation Accuracy: 0.678 | Test Accuracy: 0.687
# Epoch: 31 | Training VizWiz Accuracy: 0.646 | Validation VizWiz Accuracy: 0.746 | Test VizWiz Accuracy: 0.756
# LR: [0.00020013934986720314]
#
# Epoch: 32 | Training Loss: 2.025 | Validation Loss: 1.244 | Time 662.130
# Epoch: 32 | Training Accuracy: 0.578 | Validation Accuracy: 0.692 | Test Accuracy: 0.691
# Epoch: 32 | Training VizWiz Accuracy: 0.658 | Validation VizWiz Accuracy: 0.753 | Test VizWiz Accuracy: 0.761
# LR: [0.00020014819522672523]
#
# Epoch: 33 | Training Loss: 1.967 | Validation Loss: 1.173 | Time 661.405
# Epoch: 33 | Training Accuracy: 0.586 | Validation Accuracy: 0.702 | Test Accuracy: 0.707
# Epoch: 33 | Training VizWiz Accuracy: 0.664 | Validation VizWiz Accuracy: 0.767 | Test VizWiz Accuracy: 0.771
# LR: [0.00020015731273978227]
#
# Epoch: 34 | Training Loss: 1.908 | Validation Loss: 1.046 | Time 661.553
# Epoch: 34 | Training Accuracy: 0.591 | Validation Accuracy: 0.728 | Test Accuracy: 0.733
# Epoch: 34 | Training VizWiz Accuracy: 0.668 | Validation VizWiz Accuracy: 0.781 | Test VizWiz Accuracy: 0.787
# LR: [0.00020016670240534037]
#
# Epoch: 35 | Training Loss: 1.850 | Validation Loss: 1.026 | Time 662.059
# Epoch: 35 | Training Accuracy: 0.604 | Validation Accuracy: 0.718 | Test Accuracy: 0.726
# Epoch: 35 | Training VizWiz Accuracy: 0.678 | Validation VizWiz Accuracy: 0.781 | Test VizWiz Accuracy: 0.787
# LR: [0.0002001763642223344]
#
# Epoch: 36 | Training Loss: 1.796 | Validation Loss: 0.959 | Time 661.833
# Epoch: 36 | Training Accuracy: 0.610 | Validation Accuracy: 0.738 | Test Accuracy: 0.738
# Epoch: 36 | Training VizWiz Accuracy: 0.683 | Validation VizWiz Accuracy: 0.794 | Test VizWiz Accuracy: 0.795
# LR: [0.00020018629818966717]
#
# Epoch: 37 | Training Loss: 1.743 | Validation Loss: 0.909 | Time 662.001
# Epoch: 37 | Training Accuracy: 0.613 | Validation Accuracy: 0.736 | Test Accuracy: 0.742
# Epoch: 37 | Training VizWiz Accuracy: 0.686 | Validation VizWiz Accuracy: 0.793 | Test VizWiz Accuracy: 0.800
# LR: [0.00020019650430621455]
#
# Epoch: 38 | Training Loss: 1.679 | Validation Loss: 0.855 | Time 661.840
# Epoch: 38 | Training Accuracy: 0.629 | Validation Accuracy: 0.758 | Test Accuracy: 0.759
# Epoch: 38 | Training VizWiz Accuracy: 0.699 | Validation VizWiz Accuracy: 0.805 | Test VizWiz Accuracy: 0.812
# LR: [0.00020020698257081863]
#
# Epoch: 39 | Training Loss: 1.630 | Validation Loss: 0.766 | Time 662.395
# Epoch: 39 | Training Accuracy: 0.636 | Validation Accuracy: 0.796 | Test Accuracy: 0.785
# Epoch: 39 | Training VizWiz Accuracy: 0.705 | Validation VizWiz Accuracy: 0.835 | Test VizWiz Accuracy: 0.833
# LR: [0.00020021773298229024]
#
# Epoch: 40 | Training Loss: 1.572 | Validation Loss: 0.737 | Time 661.204
# Epoch: 40 | Training Accuracy: 0.647 | Validation Accuracy: 0.786 | Test Accuracy: 0.780
# Epoch: 40 | Training VizWiz Accuracy: 0.711 | Validation VizWiz Accuracy: 0.834 | Test VizWiz Accuracy: 0.834
# LR: [0.0002002287555394099]
#
# Epoch: 41 | Training Loss: 1.538 | Validation Loss: 0.691 | Time 661.470
# Epoch: 41 | Training Accuracy: 0.648 | Validation Accuracy: 0.794 | Test Accuracy: 0.792
# Epoch: 41 | Training VizWiz Accuracy: 0.711 | Validation VizWiz Accuracy: 0.839 | Test VizWiz Accuracy: 0.840
# LR: [0.00020024005024092944]
#
# Epoch: 42 | Training Loss: 1.470 | Validation Loss: 0.651 | Time 661.041
# Epoch: 42 | Training Accuracy: 0.663 | Validation Accuracy: 0.822 | Test Accuracy: 0.814
# Epoch: 42 | Training VizWiz Accuracy: 0.725 | Validation VizWiz Accuracy: 0.855 | Test VizWiz Accuracy: 0.854
# LR: [0.00020025161708556605]
#
# Epoch: 43 | Training Loss: 1.427 | Validation Loss: 0.611 | Time 661.657
# Epoch: 43 | Training Accuracy: 0.671 | Validation Accuracy: 0.820 | Test Accuracy: 0.814
# Epoch: 43 | Training VizWiz Accuracy: 0.730 | Validation VizWiz Accuracy: 0.853 | Test VizWiz Accuracy: 0.854
# LR: [0.00020026345607200915]
#
# Epoch: 44 | Training Loss: 1.400 | Validation Loss: 0.585 | Time 660.995
# Epoch: 44 | Training Accuracy: 0.674 | Validation Accuracy: 0.836 | Test Accuracy: 0.827
# Epoch: 44 | Training VizWiz Accuracy: 0.733 | Validation VizWiz Accuracy: 0.861 | Test VizWiz Accuracy: 0.860
# LR: [0.00020027556719891607]
#
# Epoch: 45 | Training Loss: 1.365 | Validation Loss: 0.548 | Time 660.779
# Epoch: 45 | Training Accuracy: 0.681 | Validation Accuracy: 0.844 | Test Accuracy: 0.833
# Epoch: 45 | Training VizWiz Accuracy: 0.739 | Validation VizWiz Accuracy: 0.874 | Test VizWiz Accuracy: 0.869
# LR: [0.00020028795046491289]
#
# Epoch: 46 | Training Loss: 1.316 | Validation Loss: 0.511 | Time 661.848
# Epoch: 46 | Training Accuracy: 0.689 | Validation Accuracy: 0.860 | Test Accuracy: 0.850
# Epoch: 46 | Training VizWiz Accuracy: 0.743 | Validation VizWiz Accuracy: 0.885 | Test VizWiz Accuracy: 0.881
# LR: [0.00020030060586859535]
#
# Epoch: 47 | Training Loss: 1.285 | Validation Loss: 0.504 | Time 660.828
# Epoch: 47 | Training Accuracy: 0.697 | Validation Accuracy: 0.852 | Test Accuracy: 0.843
# Epoch: 47 | Training VizWiz Accuracy: 0.749 | Validation VizWiz Accuracy: 0.888 | Test VizWiz Accuracy: 0.881
# LR: [0.00020031353340852886]
#
# Epoch: 48 | Training Loss: 1.245 | Validation Loss: 0.472 | Time 661.582
# Epoch: 48 | Training Accuracy: 0.701 | Validation Accuracy: 0.868 | Test Accuracy: 0.853
# Epoch: 48 | Training VizWiz Accuracy: 0.753 | Validation VizWiz Accuracy: 0.890 | Test VizWiz Accuracy: 0.882
# LR: [0.0002003267330832467]
#
# Epoch: 49 | Training Loss: 1.213 | Validation Loss: 0.449 | Time 660.326
# Epoch: 49 | Training Accuracy: 0.707 | Validation Accuracy: 0.880 | Test Accuracy: 0.864
# Epoch: 49 | Training VizWiz Accuracy: 0.756 | Validation VizWiz Accuracy: 0.897 | Test VizWiz Accuracy: 0.888
# LR: [0.00020034020489125177]
#
# Epoch: 50 | Training Loss: 1.185 | Validation Loss: 0.450 | Time 660.947
# Epoch: 50 | Training Accuracy: 0.712 | Validation Accuracy: 0.862 | Test Accuracy: 0.852
# Epoch: 50 | Training VizWiz Accuracy: 0.761 | Validation VizWiz Accuracy: 0.887 | Test VizWiz Accuracy: 0.883
# LR: [0.00020035394883101756]
#
# Epoch: 51 | Training Loss: 1.147 | Validation Loss: 0.437 | Time 661.035
# Epoch: 51 | Training Accuracy: 0.721 | Validation Accuracy: 0.868 | Test Accuracy: 0.855
# Epoch: 51 | Training VizWiz Accuracy: 0.767 | Validation VizWiz Accuracy: 0.888 | Test VizWiz Accuracy: 0.883
# LR: [0.00020036796490098454]
#
# Epoch: 52 | Training Loss: 1.125 | Validation Loss: 0.387 | Time 662.079
# Epoch: 52 | Training Accuracy: 0.722 | Validation Accuracy: 0.904 | Test Accuracy: 0.883
# Epoch: 52 | Training VizWiz Accuracy: 0.767 | Validation VizWiz Accuracy: 0.912 | Test VizWiz Accuracy: 0.901
# LR: [0.0002003822530995637]
#
# Epoch: 53 | Training Loss: 1.109 | Validation Loss: 0.388 | Time 662.414
# Epoch: 53 | Training Accuracy: 0.722 | Validation Accuracy: 0.890 | Test Accuracy: 0.875
# Epoch: 53 | Training VizWiz Accuracy: 0.766 | Validation VizWiz Accuracy: 0.902 | Test VizWiz Accuracy: 0.897
# LR: [0.00020039681342513306]
#
# Epoch: 54 | Training Loss: 1.084 | Validation Loss: 0.379 | Time 662.495
# Epoch: 54 | Training Accuracy: 0.728 | Validation Accuracy: 0.886 | Test Accuracy: 0.877
# Epoch: 54 | Training VizWiz Accuracy: 0.772 | Validation VizWiz Accuracy: 0.900 | Test VizWiz Accuracy: 0.898
# LR: [0.00020041164587604379]
#
# Epoch: 55 | Training Loss: 1.061 | Validation Loss: 0.360 | Time 662.394
# Epoch: 55 | Training Accuracy: 0.735 | Validation Accuracy: 0.908 | Test Accuracy: 0.890
# Epoch: 55 | Training VizWiz Accuracy: 0.777 | Validation VizWiz Accuracy: 0.913 | Test VizWiz Accuracy: 0.904
# LR: [0.00020042675045061232]
#
# Epoch: 56 | Training Loss: 1.021 | Validation Loss: 0.351 | Time 662.464
# Epoch: 56 | Training Accuracy: 0.743 | Validation Accuracy: 0.896 | Test Accuracy: 0.885
# Epoch: 56 | Training VizWiz Accuracy: 0.783 | Validation VizWiz Accuracy: 0.909 | Test VizWiz Accuracy: 0.904
# LR: [0.0002004421271471265]
#
# Epoch: 57 | Training Loss: 1.001 | Validation Loss: 0.339 | Time 661.630
# Epoch: 57 | Training Accuracy: 0.744 | Validation Accuracy: 0.908 | Test Accuracy: 0.896
# Epoch: 57 | Training VizWiz Accuracy: 0.784 | Validation VizWiz Accuracy: 0.917 | Test VizWiz Accuracy: 0.909
# LR: [0.00020045777596384116]
#
# Epoch: 58 | Training Loss: 0.990 | Validation Loss: 0.342 | Time 662.528
# Epoch: 58 | Training Accuracy: 0.746 | Validation Accuracy: 0.896 | Test Accuracy: 0.884
# Epoch: 58 | Training VizWiz Accuracy: 0.786 | Validation VizWiz Accuracy: 0.909 | Test VizWiz Accuracy: 0.902
# LR: [0.00020047369689898432]
#
# Epoch: 59 | Training Loss: 0.971 | Validation Loss: 0.314 | Time 661.933
# Epoch: 59 | Training Accuracy: 0.752 | Validation Accuracy: 0.916 | Test Accuracy: 0.901
# Epoch: 59 | Training VizWiz Accuracy: 0.789 | Validation VizWiz Accuracy: 0.921 | Test VizWiz Accuracy: 0.913
# LR: [0.0002004898899507484]
#
# Epoch: 60 | Training Loss: 0.949 | Validation Loss: 0.305 | Time 662.032
# Epoch: 60 | Training Accuracy: 0.755 | Validation Accuracy: 0.922 | Test Accuracy: 0.904
# Epoch: 60 | Training VizWiz Accuracy: 0.791 | Validation VizWiz Accuracy: 0.923 | Test VizWiz Accuracy: 0.912
# LR: [0.00020050635511729628]
#
# Epoch: 61 | Training Loss: 0.935 | Validation Loss: 0.295 | Time 661.321
# Epoch: 61 | Training Accuracy: 0.758 | Validation Accuracy: 0.920 | Test Accuracy: 0.901
# Epoch: 61 | Training VizWiz Accuracy: 0.794 | Validation VizWiz Accuracy: 0.922 | Test VizWiz Accuracy: 0.911
# LR: [0.00020052309239676318]
#
# Epoch: 62 | Training Loss: 0.916 | Validation Loss: 0.288 | Time 660.824
# Epoch: 62 | Training Accuracy: 0.760 | Validation Accuracy: 0.926 | Test Accuracy: 0.910
# Epoch: 62 | Training VizWiz Accuracy: 0.795 | Validation VizWiz Accuracy: 0.928 | Test VizWiz Accuracy: 0.918
# LR: [0.0002005401017872487]
#
# Epoch: 63 | Training Loss: 0.914 | Validation Loss: 0.269 | Time 661.669
# Epoch: 63 | Training Accuracy: 0.759 | Validation Accuracy: 0.936 | Test Accuracy: 0.918
# Epoch: 63 | Training VizWiz Accuracy: 0.793 | Validation VizWiz Accuracy: 0.931 | Test VizWiz Accuracy: 0.923
# LR: [0.0002005573832868264]
#
# Epoch: 64 | Training Loss: 0.890 | Validation Loss: 0.273 | Time 660.535
# Epoch: 64 | Training Accuracy: 0.766 | Validation Accuracy: 0.930 | Test Accuracy: 0.913
# Epoch: 64 | Training VizWiz Accuracy: 0.800 | Validation VizWiz Accuracy: 0.928 | Test VizWiz Accuracy: 0.920
# LR: [0.00020057493689353435]
#
# Epoch: 65 | Training Loss: 0.869 | Validation Loss: 0.265 | Time 659.911
# Epoch: 65 | Training Accuracy: 0.769 | Validation Accuracy: 0.936 | Test Accuracy: 0.919
# Epoch: 65 | Training VizWiz Accuracy: 0.801 | Validation VizWiz Accuracy: 0.935 | Test VizWiz Accuracy: 0.922
# LR: [0.0002005927626053828]
#
# Epoch: 66 | Training Loss: 0.854 | Validation Loss: 0.262 | Time 661.475
# Epoch: 66 | Training Accuracy: 0.776 | Validation Accuracy: 0.934 | Test Accuracy: 0.918
# Epoch: 66 | Training VizWiz Accuracy: 0.805 | Validation VizWiz Accuracy: 0.930 | Test VizWiz Accuracy: 0.923
# LR: [0.00020061086042034992]
#
# Epoch: 67 | Training Loss: 0.835 | Validation Loss: 0.263 | Time 661.702
# Epoch: 67 | Training Accuracy: 0.773 | Validation Accuracy: 0.928 | Test Accuracy: 0.915
# Epoch: 67 | Training VizWiz Accuracy: 0.803 | Validation VizWiz Accuracy: 0.929 | Test VizWiz Accuracy: 0.923
# LR: [0.00020062923033638356]
#
# Epoch: 68 | Training Loss: 0.829 | Validation Loss: 0.246 | Time 662.193
# Epoch: 68 | Training Accuracy: 0.774 | Validation Accuracy: 0.936 | Test Accuracy: 0.921
# Epoch: 68 | Training VizWiz Accuracy: 0.805 | Validation VizWiz Accuracy: 0.934 | Test VizWiz Accuracy: 0.925
# LR: [0.00020064787235139943]
#
# Epoch: 69 | Training Loss: 0.827 | Validation Loss: 0.246 | Time 662.068
# Epoch: 69 | Training Accuracy: 0.777 | Validation Accuracy: 0.938 | Test Accuracy: 0.926
# Epoch: 69 | Training VizWiz Accuracy: 0.805 | Validation VizWiz Accuracy: 0.933 | Test VizWiz Accuracy: 0.927
# LR: [0.0002006667864632855]
#
# Epoch: 70 | Training Loss: 0.808 | Validation Loss: 0.243 | Time 662.417
# Epoch: 70 | Training Accuracy: 0.783 | Validation Accuracy: 0.936 | Test Accuracy: 0.925
# Epoch: 70 | Training VizWiz Accuracy: 0.811 | Validation VizWiz Accuracy: 0.933 | Test VizWiz Accuracy: 0.926
# LR: [0.00020068597266989594]
#
# Epoch: 71 | Training Loss: 0.798 | Validation Loss: 0.231 | Time 661.453
# Epoch: 71 | Training Accuracy: 0.779 | Validation Accuracy: 0.940 | Test Accuracy: 0.923
# Epoch: 71 | Training VizWiz Accuracy: 0.809 | Validation VizWiz Accuracy: 0.935 | Test VizWiz Accuracy: 0.926
# LR: [0.00020070543096905452]
#
# Epoch: 72 | Training Loss: 0.779 | Validation Loss: 0.233 | Time 660.801
# Epoch: 72 | Training Accuracy: 0.792 | Validation Accuracy: 0.938 | Test Accuracy: 0.929
# Epoch: 72 | Training VizWiz Accuracy: 0.817 | Validation VizWiz Accuracy: 0.931 | Test VizWiz Accuracy: 0.927
# LR: [0.0002007251613585538]
#
# Epoch: 73 | Training Loss: 0.777 | Validation Loss: 0.229 | Time 660.331
# Epoch: 73 | Training Accuracy: 0.786 | Validation Accuracy: 0.944 | Test Accuracy: 0.930
# Epoch: 73 | Training VizWiz Accuracy: 0.811 | Validation VizWiz Accuracy: 0.935 | Test VizWiz Accuracy: 0.929
# LR: [0.00020074516383615862]
#
# Epoch: 74 | Training Loss: 0.752 | Validation Loss: 0.223 | Time 661.738
# Epoch: 74 | Training Accuracy: 0.791 | Validation Accuracy: 0.946 | Test Accuracy: 0.926
# Epoch: 74 | Training VizWiz Accuracy: 0.817 | Validation VizWiz Accuracy: 0.937 | Test VizWiz Accuracy: 0.928
# LR: [0.00020076543839959906]
#
# Epoch: 75 | Training Loss: 0.758 | Validation Loss: 0.216 | Time 662.000
# Epoch: 75 | Training Accuracy: 0.792 | Validation Accuracy: 0.948 | Test Accuracy: 0.931
# Epoch: 75 | Training VizWiz Accuracy: 0.817 | Validation VizWiz Accuracy: 0.938 | Test VizWiz Accuracy: 0.929
# LR: [0.00020078598504657576]
#
# Epoch: 76 | Training Loss: 0.743 | Validation Loss: 0.219 | Time 662.167
# Epoch: 76 | Training Accuracy: 0.791 | Validation Accuracy: 0.938 | Test Accuracy: 0.927
# Epoch: 76 | Training VizWiz Accuracy: 0.817 | Validation VizWiz Accuracy: 0.929 | Test VizWiz Accuracy: 0.924
# LR: [0.00020080680377475898]
#
# Epoch: 77 | Training Loss: 0.738 | Validation Loss: 0.210 | Time 661.996
# Epoch: 77 | Training Accuracy: 0.795 | Validation Accuracy: 0.952 | Test Accuracy: 0.932
# Epoch: 77 | Training VizWiz Accuracy: 0.819 | Validation VizWiz Accuracy: 0.942 | Test VizWiz Accuracy: 0.931
# LR: [0.00020082789458178776]
#
# Epoch: 78 | Training Loss: 0.725 | Validation Loss: 0.204 | Time 660.851
# Epoch: 78 | Training Accuracy: 0.797 | Validation Accuracy: 0.950 | Test Accuracy: 0.932
# Epoch: 78 | Training VizWiz Accuracy: 0.820 | Validation VizWiz Accuracy: 0.935 | Test VizWiz Accuracy: 0.928
# LR: [0.0002008492574652708]
#
# Epoch: 79 | Training Loss: 0.730 | Validation Loss: 0.206 | Time 660.384
# Epoch: 79 | Training Accuracy: 0.794 | Validation Accuracy: 0.944 | Test Accuracy: 0.931
# Epoch: 79 | Training VizWiz Accuracy: 0.819 | Validation VizWiz Accuracy: 0.933 | Test VizWiz Accuracy: 0.928
# LR: [0.00020087089242278467]
#
# Epoch: 80 | Training Loss: 0.709 | Validation Loss: 0.201 | Time 661.187
# Epoch: 80 | Training Accuracy: 0.800 | Validation Accuracy: 0.946 | Test Accuracy: 0.930
# Epoch: 80 | Training VizWiz Accuracy: 0.822 | Validation VizWiz Accuracy: 0.939 | Test VizWiz Accuracy: 0.930
# LR: [0.00020089279945187648]
#
# Epoch: 81 | Training Loss: 0.706 | Validation Loss: 0.199 | Time 660.213
# Epoch: 81 | Training Accuracy: 0.804 | Validation Accuracy: 0.950 | Test Accuracy: 0.931
# Epoch: 81 | Training VizWiz Accuracy: 0.826 | Validation VizWiz Accuracy: 0.941 | Test VizWiz Accuracy: 0.931
# LR: [0.00020091497855006038]
#
# Epoch: 82 | Training Loss: 0.686 | Validation Loss: 0.204 | Time 662.193
# Epoch: 82 | Training Accuracy: 0.806 | Validation Accuracy: 0.944 | Test Accuracy: 0.935
# Epoch: 82 | Training VizWiz Accuracy: 0.826 | Validation VizWiz Accuracy: 0.936 | Test VizWiz Accuracy: 0.931
# LR: [0.00020093742971482448]
#
# Epoch: 83 | Training Loss: 0.685 | Validation Loss: 0.199 | Time 662.126
# Epoch: 83 | Training Accuracy: 0.807 | Validation Accuracy: 0.944 | Test Accuracy: 0.933
# Epoch: 83 | Training VizWiz Accuracy: 0.827 | Validation VizWiz Accuracy: 0.939 | Test VizWiz Accuracy: 0.932
# LR: [0.0002009601529436196]
#
# Epoch: 84 | Training Loss: 0.683 | Validation Loss: 0.191 | Time 661.570
# Epoch: 84 | Training Accuracy: 0.807 | Validation Accuracy: 0.944 | Test Accuracy: 0.930
# Epoch: 84 | Training VizWiz Accuracy: 0.827 | Validation VizWiz Accuracy: 0.935 | Test VizWiz Accuracy: 0.928
# LR: [0.0002009831482338697]
#
# Epoch: 85 | Training Loss: 0.664 | Validation Loss: 0.186 | Time 661.736
# Epoch: 85 | Training Accuracy: 0.811 | Validation Accuracy: 0.946 | Test Accuracy: 0.936
# Epoch: 85 | Training VizWiz Accuracy: 0.831 | Validation VizWiz Accuracy: 0.938 | Test VizWiz Accuracy: 0.934
# LR: [0.00020100641558296745]
#
# Epoch: 86 | Training Loss: 0.671 | Validation Loss: 0.186 | Time 661.722
# Epoch: 86 | Training Accuracy: 0.808 | Validation Accuracy: 0.942 | Test Accuracy: 0.929
# Epoch: 86 | Training VizWiz Accuracy: 0.827 | Validation VizWiz Accuracy: 0.936 | Test VizWiz Accuracy: 0.929
# LR: [0.00020102995498827436]
#
# Epoch: 87 | Training Loss: 0.662 | Validation Loss: 0.179 | Time 660.954
# Epoch: 87 | Training Accuracy: 0.811 | Validation Accuracy: 0.948 | Test Accuracy: 0.935
# Epoch: 87 | Training VizWiz Accuracy: 0.831 | Validation VizWiz Accuracy: 0.938 | Test VizWiz Accuracy: 0.932
# LR: [0.00020105376644711983]
#
# Epoch: 88 | Training Loss: 0.653 | Validation Loss: 0.178 | Time 661.357
# Epoch: 88 | Training Accuracy: 0.814 | Validation Accuracy: 0.944 | Test Accuracy: 0.931
# Epoch: 88 | Training VizWiz Accuracy: 0.833 | Validation VizWiz Accuracy: 0.937 | Test VizWiz Accuracy: 0.930
# LR: [0.00020107784995680462]
#
# Epoch: 89 | Training Loss: 0.653 | Validation Loss: 0.175 | Time 661.896
# Epoch: 89 | Training Accuracy: 0.812 | Validation Accuracy: 0.952 | Test Accuracy: 0.937
# Epoch: 89 | Training VizWiz Accuracy: 0.831 | Validation VizWiz Accuracy: 0.941 | Test VizWiz Accuracy: 0.932
# LR: [0.0002011022055145974]
#
# Epoch: 90 | Training Loss: 0.648 | Validation Loss: 0.169 | Time 661.804
# Epoch: 90 | Training Accuracy: 0.816 | Validation Accuracy: 0.950 | Test Accuracy: 0.936
# Epoch: 90 | Training VizWiz Accuracy: 0.834 | Validation VizWiz Accuracy: 0.937 | Test VizWiz Accuracy: 0.932
# LR: [0.00020112683311773565]
#
# Epoch: 91 | Training Loss: 0.637 | Validation Loss: 0.169 | Time 661.240
# Epoch: 91 | Training Accuracy: 0.816 | Validation Accuracy: 0.952 | Test Accuracy: 0.937
# Epoch: 91 | Training VizWiz Accuracy: 0.834 | Validation VizWiz Accuracy: 0.942 | Test VizWiz Accuracy: 0.934
# LR: [0.00020115173276342643]
#
# Epoch: 92 | Training Loss: 0.628 | Validation Loss: 0.171 | Time 662.538
# Epoch: 92 | Training Accuracy: 0.816 | Validation Accuracy: 0.944 | Test Accuracy: 0.935
# Epoch: 92 | Training VizWiz Accuracy: 0.834 | Validation VizWiz Accuracy: 0.934 | Test VizWiz Accuracy: 0.932
# LR: [0.00020117690444884737]
#
# Epoch: 93 | Training Loss: 0.626 | Validation Loss: 0.170 | Time 662.230
# Epoch: 93 | Training Accuracy: 0.818 | Validation Accuracy: 0.950 | Test Accuracy: 0.938
# Epoch: 93 | Training VizWiz Accuracy: 0.835 | Validation VizWiz Accuracy: 0.939 | Test VizWiz Accuracy: 0.934
# LR: [0.00020120234817114224]
#
# Epoch: 94 | Training Loss: 0.617 | Validation Loss: 0.170 | Time 662.348
# Epoch: 94 | Training Accuracy: 0.820 | Validation Accuracy: 0.950 | Test Accuracy: 0.940
# Epoch: 94 | Training VizWiz Accuracy: 0.837 | Validation VizWiz Accuracy: 0.939 | Test VizWiz Accuracy: 0.935
# LR: [0.00020122806392742706]
#
# Epoch: 95 | Training Loss: 0.618 | Validation Loss: 0.169 | Time 661.539
# Epoch: 95 | Training Accuracy: 0.819 | Validation Accuracy: 0.948 | Test Accuracy: 0.937
# Epoch: 95 | Training VizWiz Accuracy: 0.836 | Validation VizWiz Accuracy: 0.938 | Test VizWiz Accuracy: 0.934
# LR: [0.00020125405171478403]
#
# Epoch: 96 | Training Loss: 0.609 | Validation Loss: 0.167 | Time 662.257
# Epoch: 96 | Training Accuracy: 0.825 | Validation Accuracy: 0.952 | Test Accuracy: 0.938
# Epoch: 96 | Training VizWiz Accuracy: 0.839 | Validation VizWiz Accuracy: 0.943 | Test VizWiz Accuracy: 0.936
# LR: [0.00020128031153026672]
#
# Epoch: 97 | Training Loss: 0.600 | Validation Loss: 0.161 | Time 661.905
# Epoch: 97 | Training Accuracy: 0.825 | Validation Accuracy: 0.952 | Test Accuracy: 0.938
# Epoch: 97 | Training VizWiz Accuracy: 0.841 | Validation VizWiz Accuracy: 0.943 | Test VizWiz Accuracy: 0.934
# LR: [0.00020130684337089748]
#
# Epoch: 98 | Training Loss: 0.604 | Validation Loss: 0.163 | Time 661.810
# Epoch: 98 | Training Accuracy: 0.823 | Validation Accuracy: 0.952 | Test Accuracy: 0.937
# Epoch: 98 | Training VizWiz Accuracy: 0.838 | Validation VizWiz Accuracy: 0.941 | Test VizWiz Accuracy: 0.932
# LR: [0.00020133364723366742]
#
# Epoch: 99 | Training Loss: 0.604 | Validation Loss: 0.159 | Time 661.434
# Epoch: 99 | Training Accuracy: 0.821 | Validation Accuracy: 0.952 | Test Accuracy: 0.936
# Epoch: 99 | Training VizWiz Accuracy: 0.837 | Validation VizWiz Accuracy: 0.938 | Test VizWiz Accuracy: 0.931
# LR: [0.00020136072311553645]
#
# Epoch: 100 | Training Loss: 0.584 | Validation Loss: 0.159 | Time 660.421
# Epoch: 100 | Training Accuracy: 0.827 | Validation Accuracy: 0.952 | Test Accuracy: 0.938
# Epoch: 100 | Training VizWiz Accuracy: 0.841 | Validation VizWiz Accuracy: 0.938 | Test VizWiz Accuracy: 0.933

# %%
# model, preprocess = clip.load("ViT-B/16", DEVICE)
# for name, param in model.named_parameters():
#     print(name)
# Out:
# positional_embedding
# text_projection
# logit_scale
# visual.class_embedding
# visual.positional_embedding
# visual.proj
# visual.conv1.weight
# visual.ln_pre.weight
# visual.ln_pre.bias
# visual.transformer.resblocks.0.attn.in_proj_weight
# visual.transformer.resblocks.0.attn.in_proj_bias
# visual.transformer.resblocks.0.attn.out_proj.weight
# visual.transformer.resblocks.0.attn.out_proj.bias
# visual.transformer.resblocks.0.ln_1.weight
# visual.transformer.resblocks.0.ln_1.bias
# visual.transformer.resblocks.0.mlp.c_fc.weight
# visual.transformer.resblocks.0.mlp.c_fc.bias
# visual.transformer.resblocks.0.mlp.c_proj.weight
# visual.transformer.resblocks.0.mlp.c_proj.bias
# visual.transformer.resblocks.0.ln_2.weight
# visual.transformer.resblocks.0.ln_2.bias
# visual.transformer.resblocks.1.attn.in_proj_weight
# visual.transformer.resblocks.1.attn.in_proj_bias
# visual.transformer.resblocks.1.attn.out_proj.weight
# visual.transformer.resblocks.1.attn.out_proj.bias
# visual.transformer.resblocks.1.ln_1.weight
# visual.transformer.resblocks.1.ln_1.bias
# visual.transformer.resblocks.1.mlp.c_fc.weight
# visual.transformer.resblocks.1.mlp.c_fc.bias
# visual.transformer.resblocks.1.mlp.c_proj.weight
# visual.transformer.resblocks.1.mlp.c_proj.bias
# visual.transformer.resblocks.1.ln_2.weight
# visual.transformer.resblocks.1.ln_2.bias
# visual.transformer.resblocks.2.attn.in_proj_weight
# visual.transformer.resblocks.2.attn.in_proj_bias
# visual.transformer.resblocks.2.attn.out_proj.weight
# visual.transformer.resblocks.2.attn.out_proj.bias
# visual.transformer.resblocks.2.ln_1.weight
# visual.transformer.resblocks.2.ln_1.bias
# visual.transformer.resblocks.2.mlp.c_fc.weight
# visual.transformer.resblocks.2.mlp.c_fc.bias
# visual.transformer.resblocks.2.mlp.c_proj.weight
# visual.transformer.resblocks.2.mlp.c_proj.bias
# visual.transformer.resblocks.2.ln_2.weight
# visual.transformer.resblocks.2.ln_2.bias
# visual.transformer.resblocks.3.attn.in_proj_weight
# visual.transformer.resblocks.3.attn.in_proj_bias
# visual.transformer.resblocks.3.attn.out_proj.weight
# visual.transformer.resblocks.3.attn.out_proj.bias
# visual.transformer.resblocks.3.ln_1.weight
# visual.transformer.resblocks.3.ln_1.bias
# visual.transformer.resblocks.3.mlp.c_fc.weight
# visual.transformer.resblocks.3.mlp.c_fc.bias
# visual.transformer.resblocks.3.mlp.c_proj.weight
# visual.transformer.resblocks.3.mlp.c_proj.bias
# visual.transformer.resblocks.3.ln_2.weight
# visual.transformer.resblocks.3.ln_2.bias
# visual.transformer.resblocks.4.attn.in_proj_weight
# visual.transformer.resblocks.4.attn.in_proj_bias
# visual.transformer.resblocks.4.attn.out_proj.weight
# visual.transformer.resblocks.4.attn.out_proj.bias
# visual.transformer.resblocks.4.ln_1.weight
# visual.transformer.resblocks.4.ln_1.bias
# visual.transformer.resblocks.4.mlp.c_fc.weight
# visual.transformer.resblocks.4.mlp.c_fc.bias
# visual.transformer.resblocks.4.mlp.c_proj.weight
# visual.transformer.resblocks.4.mlp.c_proj.bias
# visual.transformer.resblocks.4.ln_2.weight
# visual.transformer.resblocks.4.ln_2.bias
# visual.transformer.resblocks.5.attn.in_proj_weight
# visual.transformer.resblocks.5.attn.in_proj_bias
# visual.transformer.resblocks.5.attn.out_proj.weight
# visual.transformer.resblocks.5.attn.out_proj.bias
# visual.transformer.resblocks.5.ln_1.weight
# visual.transformer.resblocks.5.ln_1.bias
# visual.transformer.resblocks.5.mlp.c_fc.weight
# visual.transformer.resblocks.5.mlp.c_fc.bias
# visual.transformer.resblocks.5.mlp.c_proj.weight
# visual.transformer.resblocks.5.mlp.c_proj.bias
# visual.transformer.resblocks.5.ln_2.weight
# visual.transformer.resblocks.5.ln_2.bias
# visual.transformer.resblocks.6.attn.in_proj_weight
# visual.transformer.resblocks.6.attn.in_proj_bias
# visual.transformer.resblocks.6.attn.out_proj.weight
# visual.transformer.resblocks.6.attn.out_proj.bias
# visual.transformer.resblocks.6.ln_1.weight
# visual.transformer.resblocks.6.ln_1.bias
# visual.transformer.resblocks.6.mlp.c_fc.weight
# visual.transformer.resblocks.6.mlp.c_fc.bias
# visual.transformer.resblocks.6.mlp.c_proj.weight
# visual.transformer.resblocks.6.mlp.c_proj.bias
# visual.transformer.resblocks.6.ln_2.weight
# visual.transformer.resblocks.6.ln_2.bias
# visual.transformer.resblocks.7.attn.in_proj_weight
# visual.transformer.resblocks.7.attn.in_proj_bias
# visual.transformer.resblocks.7.attn.out_proj.weight
# visual.transformer.resblocks.7.attn.out_proj.bias
# visual.transformer.resblocks.7.ln_1.weight
# visual.transformer.resblocks.7.ln_1.bias
# visual.transformer.resblocks.7.mlp.c_fc.weight
# visual.transformer.resblocks.7.mlp.c_fc.bias
# visual.transformer.resblocks.7.mlp.c_proj.weight
# visual.transformer.resblocks.7.mlp.c_proj.bias
# visual.transformer.resblocks.7.ln_2.weight
# visual.transformer.resblocks.7.ln_2.bias
# visual.transformer.resblocks.8.attn.in_proj_weight
# visual.transformer.resblocks.8.attn.in_proj_bias
# visual.transformer.resblocks.8.attn.out_proj.weight
# visual.transformer.resblocks.8.attn.out_proj.bias
# visual.transformer.resblocks.8.ln_1.weight
# visual.transformer.resblocks.8.ln_1.bias
# visual.transformer.resblocks.8.mlp.c_fc.weight
# visual.transformer.resblocks.8.mlp.c_fc.bias
# visual.transformer.resblocks.8.mlp.c_proj.weight
# visual.transformer.resblocks.8.mlp.c_proj.bias
# visual.transformer.resblocks.8.ln_2.weight
# visual.transformer.resblocks.8.ln_2.bias
# visual.transformer.resblocks.9.attn.in_proj_weight
# visual.transformer.resblocks.9.attn.in_proj_bias
# visual.transformer.resblocks.9.attn.out_proj.weight
# visual.transformer.resblocks.9.attn.out_proj.bias
# visual.transformer.resblocks.9.ln_1.weight
# visual.transformer.resblocks.9.ln_1.bias
# visual.transformer.resblocks.9.mlp.c_fc.weight
# visual.transformer.resblocks.9.mlp.c_fc.bias
# visual.transformer.resblocks.9.mlp.c_proj.weight
# visual.transformer.resblocks.9.mlp.c_proj.bias
# visual.transformer.resblocks.9.ln_2.weight
# visual.transformer.resblocks.9.ln_2.bias
# visual.transformer.resblocks.10.attn.in_proj_weight
# visual.transformer.resblocks.10.attn.in_proj_bias
# visual.transformer.resblocks.10.attn.out_proj.weight
# visual.transformer.resblocks.10.attn.out_proj.bias
# visual.transformer.resblocks.10.ln_1.weight
# visual.transformer.resblocks.10.ln_1.bias
# visual.transformer.resblocks.10.mlp.c_fc.weight
# visual.transformer.resblocks.10.mlp.c_fc.bias
# visual.transformer.resblocks.10.mlp.c_proj.weight
# visual.transformer.resblocks.10.mlp.c_proj.bias
# visual.transformer.resblocks.10.ln_2.weight
# visual.transformer.resblocks.10.ln_2.bias
# visual.transformer.resblocks.11.attn.in_proj_weight
# visual.transformer.resblocks.11.attn.in_proj_bias
# visual.transformer.resblocks.11.attn.out_proj.weight
# visual.transformer.resblocks.11.attn.out_proj.bias
# visual.transformer.resblocks.11.ln_1.weight
# visual.transformer.resblocks.11.ln_1.bias
# visual.transformer.resblocks.11.mlp.c_fc.weight
# visual.transformer.resblocks.11.mlp.c_fc.bias
# visual.transformer.resblocks.11.mlp.c_proj.weight
# visual.transformer.resblocks.11.mlp.c_proj.bias
# visual.transformer.resblocks.11.ln_2.weight
# visual.transformer.resblocks.11.ln_2.bias
# visual.ln_post.weight
# visual.ln_post.bias
# transformer.resblocks.0.attn.in_proj_weight
# transformer.resblocks.0.attn.in_proj_bias
# transformer.resblocks.0.attn.out_proj.weight
# transformer.resblocks.0.attn.out_proj.bias
# transformer.resblocks.0.ln_1.weight
# transformer.resblocks.0.ln_1.bias
# transformer.resblocks.0.mlp.c_fc.weight
# transformer.resblocks.0.mlp.c_fc.bias
# transformer.resblocks.0.mlp.c_proj.weight
# transformer.resblocks.0.mlp.c_proj.bias
# transformer.resblocks.0.ln_2.weight
# transformer.resblocks.0.ln_2.bias
# transformer.resblocks.1.attn.in_proj_weight
# transformer.resblocks.1.attn.in_proj_bias
# transformer.resblocks.1.attn.out_proj.weight
# transformer.resblocks.1.attn.out_proj.bias
# transformer.resblocks.1.ln_1.weight
# transformer.resblocks.1.ln_1.bias
# transformer.resblocks.1.mlp.c_fc.weight
# transformer.resblocks.1.mlp.c_fc.bias
# transformer.resblocks.1.mlp.c_proj.weight
# transformer.resblocks.1.mlp.c_proj.bias
# transformer.resblocks.1.ln_2.weight
# transformer.resblocks.1.ln_2.bias
# transformer.resblocks.2.attn.in_proj_weight
# transformer.resblocks.2.attn.in_proj_bias
# transformer.resblocks.2.attn.out_proj.weight
# transformer.resblocks.2.attn.out_proj.bias
# transformer.resblocks.2.ln_1.weight
# transformer.resblocks.2.ln_1.bias
# transformer.resblocks.2.mlp.c_fc.weight
# transformer.resblocks.2.mlp.c_fc.bias
# transformer.resblocks.2.mlp.c_proj.weight
# transformer.resblocks.2.mlp.c_proj.bias
# transformer.resblocks.2.ln_2.weight
# transformer.resblocks.2.ln_2.bias
# transformer.resblocks.3.attn.in_proj_weight
# transformer.resblocks.3.attn.in_proj_bias
# transformer.resblocks.3.attn.out_proj.weight
# transformer.resblocks.3.attn.out_proj.bias
# transformer.resblocks.3.ln_1.weight
# transformer.resblocks.3.ln_1.bias
# transformer.resblocks.3.mlp.c_fc.weight
# transformer.resblocks.3.mlp.c_fc.bias
# transformer.resblocks.3.mlp.c_proj.weight
# transformer.resblocks.3.mlp.c_proj.bias
# transformer.resblocks.3.ln_2.weight
# transformer.resblocks.3.ln_2.bias
# transformer.resblocks.4.attn.in_proj_weight
# transformer.resblocks.4.attn.in_proj_bias
# transformer.resblocks.4.attn.out_proj.weight
# transformer.resblocks.4.attn.out_proj.bias
# transformer.resblocks.4.ln_1.weight
# transformer.resblocks.4.ln_1.bias
# transformer.resblocks.4.mlp.c_fc.weight
# transformer.resblocks.4.mlp.c_fc.bias
# transformer.resblocks.4.mlp.c_proj.weight
# transformer.resblocks.4.mlp.c_proj.bias
# transformer.resblocks.4.ln_2.weight
# transformer.resblocks.4.ln_2.bias
# transformer.resblocks.5.attn.in_proj_weight
# transformer.resblocks.5.attn.in_proj_bias
# transformer.resblocks.5.attn.out_proj.weight
# transformer.resblocks.5.attn.out_proj.bias
# transformer.resblocks.5.ln_1.weight
# transformer.resblocks.5.ln_1.bias
# transformer.resblocks.5.mlp.c_fc.weight
# transformer.resblocks.5.mlp.c_fc.bias
# transformer.resblocks.5.mlp.c_proj.weight
# transformer.resblocks.5.mlp.c_proj.bias
# transformer.resblocks.5.ln_2.weight
# transformer.resblocks.5.ln_2.bias
# transformer.resblocks.6.attn.in_proj_weight
# transformer.resblocks.6.attn.in_proj_bias
# transformer.resblocks.6.attn.out_proj.weight
# transformer.resblocks.6.attn.out_proj.bias
# transformer.resblocks.6.ln_1.weight
# transformer.resblocks.6.ln_1.bias
# transformer.resblocks.6.mlp.c_fc.weight
# transformer.resblocks.6.mlp.c_fc.bias
# transformer.resblocks.6.mlp.c_proj.weight
# transformer.resblocks.6.mlp.c_proj.bias
# transformer.resblocks.6.ln_2.weight
# transformer.resblocks.6.ln_2.bias
# transformer.resblocks.7.attn.in_proj_weight
# transformer.resblocks.7.attn.in_proj_bias
# transformer.resblocks.7.attn.out_proj.weight
# transformer.resblocks.7.attn.out_proj.bias
# transformer.resblocks.7.ln_1.weight
# transformer.resblocks.7.ln_1.bias
# transformer.resblocks.7.mlp.c_fc.weight
# transformer.resblocks.7.mlp.c_fc.bias
# transformer.resblocks.7.mlp.c_proj.weight
# transformer.resblocks.7.mlp.c_proj.bias
# transformer.resblocks.7.ln_2.weight
# transformer.resblocks.7.ln_2.bias
# transformer.resblocks.8.attn.in_proj_weight
# transformer.resblocks.8.attn.in_proj_bias
# transformer.resblocks.8.attn.out_proj.weight
# transformer.resblocks.8.attn.out_proj.bias
# transformer.resblocks.8.ln_1.weight
# transformer.resblocks.8.ln_1.bias
# transformer.resblocks.8.mlp.c_fc.weight
# transformer.resblocks.8.mlp.c_fc.bias
# transformer.resblocks.8.mlp.c_proj.weight
# transformer.resblocks.8.mlp.c_proj.bias
# transformer.resblocks.8.ln_2.weight
# transformer.resblocks.8.ln_2.bias
# transformer.resblocks.9.attn.in_proj_weight
# transformer.resblocks.9.attn.in_proj_bias
# transformer.resblocks.9.attn.out_proj.weight
# transformer.resblocks.9.attn.out_proj.bias
# transformer.resblocks.9.ln_1.weight
# transformer.resblocks.9.ln_1.bias
# transformer.resblocks.9.mlp.c_fc.weight
# transformer.resblocks.9.mlp.c_fc.bias
# transformer.resblocks.9.mlp.c_proj.weight
# transformer.resblocks.9.mlp.c_proj.bias
# transformer.resblocks.9.ln_2.weight
# transformer.resblocks.9.ln_2.bias
# transformer.resblocks.10.attn.in_proj_weight
# transformer.resblocks.10.attn.in_proj_bias
# transformer.resblocks.10.attn.out_proj.weight
# transformer.resblocks.10.attn.out_proj.bias
# transformer.resblocks.10.ln_1.weight
# transformer.resblocks.10.ln_1.bias
# transformer.resblocks.10.mlp.c_fc.weight
# transformer.resblocks.10.mlp.c_fc.bias
# transformer.resblocks.10.mlp.c_proj.weight
# transformer.resblocks.10.mlp.c_proj.bias
# transformer.resblocks.10.ln_2.weight
# transformer.resblocks.10.ln_2.bias
# transformer.resblocks.11.attn.in_proj_weight
# transformer.resblocks.11.attn.in_proj_bias
# transformer.resblocks.11.attn.out_proj.weight
# transformer.resblocks.11.attn.out_proj.bias
# transformer.resblocks.11.ln_1.weight
# transformer.resblocks.11.ln_1.bias
# transformer.resblocks.11.mlp.c_fc.weight
# transformer.resblocks.11.mlp.c_fc.bias
# transformer.resblocks.11.mlp.c_proj.weight
# transformer.resblocks.11.mlp.c_proj.bias
# transformer.resblocks.11.ln_2.weight
# transformer.resblocks.11.ln_2.bias
# token_embedding.weight
# ln_final.weight
# ln_final.bias

# %%
df = pd.read_json("./data/valid.json")
df = df[['image', 'question']]

# let's create two json objects to store the output of the model then write them to a file
model_answers = []

for i in tqdm(range(len(df))):
    image_url = df['image'][i]
    question = df['question'][i]
    image_path = VALIDATION_PATH + "/" + image_url
    predicted_answer = model.test_model(image_path = image_path, question = question)
    answer = ANSWER_ONEHOTENCODER.inverse_transform(predicted_answer.cpu().detach().numpy())
    answer_result = {'image': image_url, 'answer': answer[0][0]}
    model_answers.append(answer_result)
# Out:
#   0%|          | 11/4969 [00:00<06:11, 13.35it/s]

# %%
submission = np.array([ans['answer'] for ans in model_answers])
np.save("submission.npy", submission)

# save to drive
DATA_PATH = '/content/drive/MyDrive/matsuo-ken-2024-DL/VQA/'
# add timestamp to name
import time
time_stamp = time.strftime("%Y%m%d-%H%M%S")
torch.save(model.state_dict(), DATA_PATH + 'model_' + time_stamp + '_.pth')
np.save(DATA_PATH + 'submission_' + time_stamp, submission)

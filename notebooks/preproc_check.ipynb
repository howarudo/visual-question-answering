# %%
from src.utils import *
from src.dataset import *

# %%
train_df = load_df('data/train.json')
train_df
# Out:
#                  image                                           question  \
# 0      train_00000.jpg                                      What is this?
# 1      train_00001.jpg  maybe it's because you're pushing it down instead
# 2      train_00002.jpg                           What color is this item?
# 3      train_00003.jpg  Can you tell me if this is like body wash or l...
# 4      train_00004.jpg                                     Is it a paper?
# ...                ...                                                ...
# 19868  train_19868.jpg                        What's on this card please?
# 19869  train_19869.jpg         I can't tell what it is that I'm holding.
# 19870  train_19870.jpg                    What does it say on this shirt?
# 19871  train_19871.jpg  I'm looking for the model number of this print...
# 19872  train_19872.jpg  Is there any writing on this side of the packa...
#
#                                                  answers
# ...

# %%
train_dataset = VQATrainDataset(train_df, 'data/train')
# Out:
# 100%|██████████| 19873/19873 [00:00<00:00, 27530.68it/s]

# %%
train_dataset.answers[:100]
# Out:
# ['beef chuck steak',
#  'unanswerable',
#  'grey',
#  'lotion',
#  'no',
#  'sun chips',
#  'shampoo',
#  'unanswerable',
#  'paper',
#  'brown',
#  'hot',
#  'unanswerable',
#  'pink',
#  '1 dollar',
#  'unanswerable',
#  'blue',
#  'soup',
#  'television',
#  'brown',
#  'unanswerable',
#  'unanswerable',
#  'purple',
#  'sunny paris seasoning',
#  'unanswerable',
#  'unanswerable',
#  'milk',
#  'duffle bag on bed',
#  'unanswerable',
#  'unanswerable',
#  'unanswerable',
#  '1 dollar bill',
#  'unanswerable',
#  'unanswerable',
#  'unanswerable',
#  'mac os x',
#  'scuderia ferrari',
#  'unanswerable',
#  'yes',
#  'no',
#  'lock computer switch user log off change password start task manager cancel',
#  'steak rub',
#  'unanswerable',
#  'unanswerable',
#  'unanswerable',
#  'lemon pepper',
#  'unanswerable',
#  'unanswerable',
#  'unanswerable',
#  'box teabags',
#  'green',
#  'pink',
#  'traffic cones',
#  'pain relief pm',
#  '1:48',
#  'unanswerable',
#  'unanswerable',
# ...
